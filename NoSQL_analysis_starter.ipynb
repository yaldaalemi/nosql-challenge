# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
# Import PyMongo
from pymongo import MongoClient
# Import pprint
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
estab = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq': 20}}

# Use count_documents to display the number of documents in the result
print(estab.count_documents(query))

# Display the first document in the results using pprint
pprint(estab.find_one(query))
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3c5c32cdb164c1a72d'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results = list(estab.find(query))
hygiene = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygiene))
# Display the first 10 rows of the DataFrame
hygiene.head(10)
# Out:
# Rows in DataFrame:  2115
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d95f3c5c32cdb164c1b106   637054                  0
# 1  63d95f3c5c32cdb164c1b108   174020                  0
# 2  63d95f3c5c32cdb164c1b109   664257                  0
# 3  63d95f3c5c32cdb164c1b159   174047                  0
# 4  63d95f3c5c32cdb164c1b162   173610                  0
# 5  63d95f3c5c32cdb164c1b199   799755                  0
# 6  63d95f3c5c32cdb164c1b1e4   173738                  0
# 7  63d95f3c5c32cdb164c1b1f2  1379100                  0
# 8  63d95f3c5c32cdb164c1b1f4   964681                  0
# 9  63d95f3c5c32cdb164c1b335   167791                  0
#
#   LocalAuthorityBusinessID                        BusinessName  \
# 0             PI/000061384                Costcutter Claremont
# 1             PI/000027807                   Angies Newsagents
# 2             PI/000027811                      R & B Fish Bar
# 3             PI/000027871  Clifden House Dementia Care Centre
# 4             PI/000026322                Beachlands Care Home
# 5             PI/000062948             Co-Operative Food Store
# 6             PI/000026802                        Ab Fab Rooms
# 7             PI/000067734              The Tide at The Buckle
# 8             PI/000026347                          Buckle B&B
# 9             PI/000012107                        The Hope Inn
#
#                             BusinessType  BusinessTypeID  \
# 0                      Retailers - other            4613
# 1                      Retailers - other            4613
# 2                 Takeaway/sandwich shop            7844
# 3                        Caring Premises               5
# 4                        Caring Premises               5
# 5  Retailers - supermarkets/hypermarkets            7840
# 6      Hotel/bed & breakfast/guest house            7842
# 7                Restaurant/Cafe/Canteen               1
# 8      Hotel/bed & breakfast/guest house            7842
# 9                      Pub/bar/nightclub            7843
#
#                       AddressLine1        AddressLine2 AddressLine3  ...  \
# 0             29-31 Claremont Road             Seaford  East Sussex  ...
# 1                23 Claremont Road             Seaford  East Sussex  ...
# 2                25 Claremont Road             Seaford  East Sussex  ...
# 3             80-88 Claremont Road             Seaford  East Sussex  ...
# 4                    Marine Parade             Seaford  East Sussex  ...
# 5                    Units 1 And 2  123 Princess Drive      Seaford  ...
# 6                  11 Station Road             Seaford  East Sussex  ...
# 7  Buckle Camping And Caravan Park       Marine Parade      Seaford  ...
# 8                       The Buckle       Marine Parade      Seaford  ...
# 9                     24 Fort Gate           Fort Road     Newhaven  ...
#
#                  LocalAuthorityWebSite           LocalAuthorityEmailAddress  \
# 0  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 1  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 2  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 3  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 4  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 5  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 6  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 7  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 8  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 9  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                           geocode RightToReply     Distance  \
# 0   {'longitude': 0.093059, 'latitude': 50.77601}               4620.941087
# 1   {'longitude': 0.093059, 'latitude': 50.77601}               4620.941087
# 2   {'longitude': 0.093059, 'latitude': 50.77601}               4620.941087
# 3  {'longitude': 0.089886, 'latitude': 50.776112}               4621.062631
# 4  {'longitude': 0.088903, 'latitude': 50.775392}               4621.072928
# 5  {'longitude': 0.091359, 'latitude': 50.781491}               4621.203745
# 6  {'longitude': 0.083468, 'latitude': 50.780751}               4621.469819
# 7   {'longitude': 0.08091, 'latitude': 50.779367}               4621.514440
# 8  {'longitude': 0.080909, 'latitude': 50.779366}               4621.514441
# 9  {'longitude': 0.055837, 'latitude': 50.782761}               4622.569119
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={'LocalAuthorityName': {'$regex': 'London'},
         'RatingValue': {'$gte': '4'}}

# Use count_documents to display the number of documents in the result
print(estab.count_documents(query))

# Display the first document in the results using pprint
pprint(estab.find_one(query))
# Out:
# 34
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3d5c32cdb164c1c147'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
results = list(estab.find(query))
London = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(London))
# Display the first 10 rows of the DataFrame
London.head(10)
# Out:
# Rows in DataFrame:  2115
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d95f3c5c32cdb164c1b106   637054                  0
# 1  63d95f3c5c32cdb164c1b108   174020                  0
# 2  63d95f3c5c32cdb164c1b109   664257                  0
# 3  63d95f3c5c32cdb164c1b159   174047                  0
# 4  63d95f3c5c32cdb164c1b162   173610                  0
# 5  63d95f3c5c32cdb164c1b199   799755                  0
# 6  63d95f3c5c32cdb164c1b1e4   173738                  0
# 7  63d95f3c5c32cdb164c1b1f2  1379100                  0
# 8  63d95f3c5c32cdb164c1b1f4   964681                  0
# 9  63d95f3c5c32cdb164c1b335   167791                  0
#
#   LocalAuthorityBusinessID                        BusinessName  \
# 0             PI/000061384                Costcutter Claremont
# 1             PI/000027807                   Angies Newsagents
# 2             PI/000027811                      R & B Fish Bar
# 3             PI/000027871  Clifden House Dementia Care Centre
# 4             PI/000026322                Beachlands Care Home
# 5             PI/000062948             Co-Operative Food Store
# 6             PI/000026802                        Ab Fab Rooms
# 7             PI/000067734              The Tide at The Buckle
# 8             PI/000026347                          Buckle B&B
# 9             PI/000012107                        The Hope Inn
#
#                             BusinessType  BusinessTypeID  \
# 0                      Retailers - other            4613
# 1                      Retailers - other            4613
# 2                 Takeaway/sandwich shop            7844
# 3                        Caring Premises               5
# 4                        Caring Premises               5
# 5  Retailers - supermarkets/hypermarkets            7840
# 6      Hotel/bed & breakfast/guest house            7842
# 7                Restaurant/Cafe/Canteen               1
# 8      Hotel/bed & breakfast/guest house            7842
# 9                      Pub/bar/nightclub            7843
#
#                       AddressLine1        AddressLine2 AddressLine3  ...  \
# 0             29-31 Claremont Road             Seaford  East Sussex  ...
# 1                23 Claremont Road             Seaford  East Sussex  ...
# 2                25 Claremont Road             Seaford  East Sussex  ...
# 3             80-88 Claremont Road             Seaford  East Sussex  ...
# 4                    Marine Parade             Seaford  East Sussex  ...
# 5                    Units 1 And 2  123 Princess Drive      Seaford  ...
# 6                  11 Station Road             Seaford  East Sussex  ...
# 7  Buckle Camping And Caravan Park       Marine Parade      Seaford  ...
# 8                       The Buckle       Marine Parade      Seaford  ...
# 9                     24 Fort Gate           Fort Road     Newhaven  ...
#
#                  LocalAuthorityWebSite           LocalAuthorityEmailAddress  \
# 0  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 1  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 2  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 3  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 4  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 5  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 6  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 7  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 8  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
# 9  http://www.lewes-eastbourne.gov.uk/  ehealth.ldc@lewes-eastbourne.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                           geocode RightToReply     Distance  \
# 0   {'longitude': 0.093059, 'latitude': 50.77601}               4620.941087
# 1   {'longitude': 0.093059, 'latitude': 50.77601}               4620.941087
# 2   {'longitude': 0.093059, 'latitude': 50.77601}               4620.941087
# 3  {'longitude': 0.089886, 'latitude': 50.776112}               4621.062631
# 4  {'longitude': 0.088903, 'latitude': 50.775392}               4621.072928
# 5  {'longitude': 0.091359, 'latitude': 50.781491}               4621.203745
# 6  {'longitude': 0.083468, 'latitude': 50.780751}               4621.469819
# 7   {'longitude': 0.08091, 'latitude': 50.779367}               4621.514440
# 8  {'longitude': 0.080909, 'latitude': 50.779366}               4621.514441
# 9  {'longitude': 0.055837, 'latitude': 50.782761}               4622.569119
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query ={'geocode.latitude': {'$gte': (latitude - degree_search)},
         'geocode.latitude': {'$lte': (latitude + degree_search)},
        'geocode.longitude': {'$gte': (longitude - degree_search)},
         'geocode.longitude': {'$lte': (longitude + degree_search)},
       'RatingValue': {'$eq': '5'}}
sort = [('scores.Hygiene', 1)]
limit = 5
results = estab.find(query).sort(sort).limit(limit)

# Pretty print the first five results
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '59 High Street',
#  'AddressLine2': 'Edenbridge',
#  'AddressLine3': 'KENT',
#  'AddressLine4': '',
#  'BusinessName': 'Magic Wok',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4637.314456896255,
#  'FHRSID': 266978,
#  'LocalAuthorityBusinessID': '11/00025/MIXED',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN8 5AL',
#  'RatingDate': '2022-03-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3e5c32cdb164c1de89'),
#  'geocode': {'latitude': 51.196736, 'longitude': 0.065179},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/266978',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '9 Hartfield Road',
#  'AddressLine2': 'Forest Row',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Roochi Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4634.823529709642,
#  'FHRSID': 162872,
#  'LocalAuthorityBusinessID': 'PI/000003806',
#  'LocalAuthorityCode': '107',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Wealden',
#  'LocalAuthorityWebSite': 'http://www.wealden.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RH18 5DN',
#  'RatingDate': '2021-07-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3d5c32cdb164c1d6fe'),
#  'geocode': {'latitude': 51.097521, 'longitude': 0.034461},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/162872',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Wolf House',
#  'AddressLine2': 'Wolfs Row',
#  'AddressLine3': '',
#  'AddressLine4': 'Limpsfield',
#  'BusinessName': 'Wolfe House Resid. Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4641.271316270499,
#  'FHRSID': 105360,
#  'LocalAuthorityBusinessID': '36199',
#  'LocalAuthorityCode': '313',
#  'LocalAuthorityEmailAddress': 'fsa_enforcement@tandridge.gov.uk',
#  'LocalAuthorityName': 'Tandridge',
#  'LocalAuthorityWebSite': 'http://www.tandridge.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RH8 0EB',
#  'RatingDate': '2022-06-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3e5c32cdb164c1e75a'),
#  'geocode': {'latitude': 51.255431, 'longitude': 0.015813},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/105360',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '1 Winterton Court',
#  'AddressLine2': 'Market Square',
#  'AddressLine3': 'Westerham',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Sultan Kebab House',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4639.681032207483,
#  'FHRSID': 266897,
#  'LocalAuthorityBusinessID': '09200/2000/2/000',
#  'LocalAuthorityCode': '187',
#  'LocalAuthorityEmailAddress': 'environmental.health@sevenoaks.gov.uk',
#  'LocalAuthorityName': 'Sevenoaks',
#  'LocalAuthorityWebSite': 'http://www.sevenoaks.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN16 1AL',
#  'RatingDate': '2022-03-03T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3e5c32cdb164c1e313'),
#  'geocode': {'latitude': 51.266922, 'longitude': 0.070589},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/266897',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'North Hall Farm',
#  'AddressLine2': 'North Hall Lane',
#  'AddressLine3': 'Fletching',
#  'AddressLine4': 'East Sussex',
#  'BusinessName': 'Northall CPC',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4631.9412296579985,
#  'FHRSID': 184934,
#  'LocalAuthorityBusinessID': 'PI/400005256',
#  'LocalAuthorityCode': '107',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Wealden',
#  'LocalAuthorityWebSite': 'http://www.wealden.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN22 3SA',
#  'RatingDate': '2022-03-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d95f3d5c32cdb164c1cf89'),
#  'geocode': {'latitude': 51.006613, 'longitude': 0.022783},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/184934',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}

# %%
# Convert result to Pandas DataFrame
rating = pd.DataFrame(list(estab.find(query).sort(sort).limit(limit)))
rating.head()
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  63d95f3e5c32cdb164c1de89  266978                  0
# 1  63d95f3d5c32cdb164c1d6fe  162872                  0
# 2  63d95f3e5c32cdb164c1e75a  105360                  0
# 3  63d95f3e5c32cdb164c1e313  266897                  0
# 4  63d95f3d5c32cdb164c1cf89  184934                  0
#
#   LocalAuthorityBusinessID             BusinessName             BusinessType  \
# 0           11/00025/MIXED                Magic Wok  Other catering premises
# 1             PI/000003806               Roochi Ltd  Restaurant/Cafe/Canteen
# 2                    36199  Wolfe House Resid. Home          Caring Premises
# 3         09200/2000/2/000       Sultan Kebab House   Takeaway/sandwich shop
# 4             PI/400005256             Northall CPC        Pub/bar/nightclub
#
#    BusinessTypeID       AddressLine1     AddressLine2 AddressLine3  ...  \
# 0            7841     59 High Street       Edenbridge         KENT  ...
# 1               1   9 Hartfield Road       Forest Row  East Sussex  ...
# 2               5         Wolf House        Wolfs Row               ...
# 3            7844  1 Winterton Court    Market Square    Westerham  ...
# 4            7843    North Hall Farm  North Hall Lane    Fletching  ...
#
#           LocalAuthorityWebSite             LocalAuthorityEmailAddress  \
# 0  http://www.sevenoaks.gov.uk/  environmental.health@sevenoaks.gov.uk
# 1     http://www.wealden.gov.uk                envhealth@rother.gov.uk
# 2  http://www.tandridge.gov.uk/       fsa_enforcement@tandridge.gov.uk
# 3  http://www.sevenoaks.gov.uk/  environmental.health@sevenoaks.gov.uk
# 4     http://www.wealden.gov.uk                envhealth@rother.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 1  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 2  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 3  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 4  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
#
#                                           geocode RightToReply     Distance  \
# 0  {'longitude': 0.065179, 'latitude': 51.196736}               4637.314457
# 1  {'longitude': 0.034461, 'latitude': 51.097521}               4634.823530
# 2  {'longitude': 0.015813, 'latitude': 51.255431}               4641.271316
# 3  {'longitude': 0.070589, 'latitude': 51.266922}               4639.681032
# 4  {'longitude': 0.022783, 'latitude': 51.006613}               4631.941230
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': {'$eq': 0}}}
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1 }}
pipeline = [match_query, group_query, sort_values]
# Print the number of documents in the result
results = estab.aggregate(pipeline)
# Print the first 10 results
i=0
for result in results:
    if i in range(10):
        pprint(result)
        i = i+1
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
data = list(estab.aggregate(pipeline))
local = pd.DataFrame(data)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(local))
# Display the first 10 rows of the DataFrame
local.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
